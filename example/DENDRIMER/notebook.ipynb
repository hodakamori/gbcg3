# %%
from gbcg3.cgmapping import AA2CG

# %%
aa2cg = AA2CG(
        traj=["coords.lammpstrj"],
        data="sys.data",
        niter=5,
        min_level=[2, 2, 2, 2, 2],
        max_level=[6, 6, 6, 6, 6],
        output_dir="output",
        names="lmps2type.map",
    )
aa2cg.run()
# Out:
# 2023-07-06 09:24:40 [INFO] cgmapping.py:38 - Screening files
# 2023-07-06 09:24:40 [INFO] lammps.py:87 - # Extracting masses from sys.data ...
# 2023-07-06 09:24:40 [INFO] lammps.py:93 - # A total of 3 atom types reported!!!
# 2023-07-06 09:24:40 [INFO] lammps.py:100 - # Masses field found and recorded! Breaking from file...
# 2023-07-06 09:24:40 [INFO] lammps.py:113 - # Extracting topology from sys.data ...
# 2023-07-06 09:24:40 [INFO] lammps.py:119 - # A total of 100 bonds reported!!!
# 2023-07-06 09:24:41 [INFO] lammps.py:128 - # Bonds field found and recorded! Breaking from file...
# 2023-07-06 09:24:41 [INFO] lammps.py:141 - # Total number of atoms to be assigned: 101
# 2023-07-06 09:24:41 [INFO] lammps.py:162 - # Total number of molecules: 1
# 2023-07-06 09:24:41 [INFO] lammps.py:167 - #---Number of atoms in mol 0: 101
# 2023-07-06 09:24:41 [INFO] gbcg.py:122 - Reduction Summary for molecule 0
#
#
# 2023-07-06 09:24:41 [INFO] core.py:673 - Initial Number of atoms: 101
# ...
