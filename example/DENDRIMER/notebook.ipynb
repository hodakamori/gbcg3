# %%
from gbcg3 import AA2CG

# %%
aa2cg = AA2CG(
        traj=["coords.lammpstrj"],
        data="sys.data",
        niter=5,
        min_level=[2, 2, 2, 2, 2],
        max_level=[6, 6, 6, 6, 6],
        output_dir="output",
        name_mapfile="lmps2type.map",
    )
aa2cg.run()
# Out:
# 2023-07-16 08:52:38 [INFO] cgmapping.py:39 - Screening files
# 2023-07-16 08:52:38 [INFO] aux.py:79 - # Extracting masses from sys.data ...
# 2023-07-16 08:52:38 [INFO] aux.py:85 - # A total of 3 atom types reported!!!
# 2023-07-16 08:52:38 [INFO] aux.py:92 - # Masses field found and recorded! Breaking from file...
# 2023-07-16 08:52:38 [INFO] aux.py:103 - # Extracting topology from sys.data ...
# 2023-07-16 08:52:38 [INFO] aux.py:109 - # A total of 100 bonds reported!!!
# 2023-07-16 08:52:38 [INFO] aux.py:118 - # Bonds field found and recorded! Breaking from file...
# 2023-07-16 08:52:38 [INFO] lammps.py:23 - # Total number of atoms to be assigned: 101
# 2023-07-16 08:52:38 [INFO] lammps.py:44 - # Total number of molecules: 1
# 2023-07-16 08:52:38 [INFO] lammps.py:49 - #---Number of atoms in mol 0: 101
# 2023-07-16 08:52:38 [INFO] gbcg.py:124 - Reduction Summary for molecule 0
#
#
# 2023-07-16 08:52:38 [INFO] core.py:667 - Initial Number of atoms: 101
# ...
