# %%
from gbcg3 import AA2CG

# %%
aa2cg = AA2CG(
        traj=["polymer.lammpstrj"],
        data="polymer.data",
        niter=8,
        min_level=[2, 2, 2, 2, 2, 2, 2, 2],
        max_level=[6, 6, 6, 6, 6, 6, 6, 6],
        output_dir="output",
        max_samp=1
    )
aa2cg.run()
# Out:
# 2023-07-20 20:41:40 [INFO] cgmapping.py:39 - Screening files
# 2023-07-20 20:41:40 [INFO] data.py:11 - # Extracting masses from polymer.data ...
# 2023-07-20 20:41:40 [INFO] data.py:17 - # A total of 6 atom types reported!!!
# 2023-07-20 20:41:40 [INFO] data.py:24 - # Masses field found and recorded! Breaking from file...
# 2023-07-20 20:41:40 [INFO] data.py:35 - # Extracting topology from polymer.data ...
# 2023-07-20 20:41:40 [INFO] data.py:41 - # A total of 1507 bonds reported!!!
# 2023-07-20 20:41:40 [INFO] data.py:50 - # Bonds field found and recorded! Breaking from file...
# 2023-07-20 20:41:40 [INFO] lammps.py:25 - # Total number of atoms to be assigned: 1508
# 2023-07-20 20:41:40 [INFO] lammps.py:46 - # Total number of molecules: 1
# 2023-07-20 20:41:40 [INFO] lammps.py:51 - #---Number of atoms in mol 0: 1508
# 2023-07-20 20:41:40 [INFO] gbcg.py:89 - Reduction Summary for molecule 0
#
#
# 2023-07-20 20:41:40 [INFO] core.py:499 - Initial Number of atoms: 1508
# ...
